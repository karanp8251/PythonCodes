# %%
#first program
print("Acropolis")
#same values to different variables
var1 = var2 = var3 = 1
print(var1,' ',var2,' ',var3)
#different values to different variables
var4, var5, var6 = 1, "Aniruddha", "Sharma"
print(var4,' ',var5,' ',var6)
# Out:
# Acropolis
# 1   1   1

# %%
#add number
age = input("Enter your age: ")
age = int(age) + 5
print(age)
# Out:
# Enter your age: 5
# 10

# %%
#type casting
a = 10
print(str(a))
print(float(a))

b = "20"
print(int(b))
print(float(b))

c = 23.56
print(int(c))
print(str(c))
# Out:
# 10
# 10.0
# 20
# 20.0
# 23
# 23.56

# %%
print("{}, A computer science portal for acropolis.".format("acropolis"))
var1 = "This article is written in {}"
print(var1.format("python"))
print("Hello! i am {} years old.".format(21))
# Out:
# acropolis, A computer science portal for acropolis.
# This article is written in python
# Hello! i am 21 years old.

# %%
#characters and there ASCII
x=68
print(chr(x))
char="D"
print(ord(char))
# Out:
# D
# 68

# %%
#code to write 5 times
print('ACROPOLIS\n'*5)
# Out:
# ACROPOLIS
# ACROPOLIS
# ACROPOLIS
# ACROPOLIS
# ACROPOLIS

# %%
#for loop
for i in range(5):
  print('*'*1)

print('\n')
for i in range(1, 4, 1):
  print('*'*i)
# Out:
# *
# *
# *
# *
# *
#
#
# *
# **
# ***

# %%
for i in range(1,6):
  print(" "*(6-1), "*"*i)
# Out:
#       *
#       **
#       ***
#       ****
#       *****

# %%
a, b, c = 10, 20, 30
print(a, b, c, sep = ':', end= '.')
# Out:
# 10:20:30.

# %%
word = 'pyhton'
a, b, c, d, e, f = word
print(a, b, c, d, e, f)
# Out:
# p y h t o n

# %%
print('I like {0} of {1} flav')

# %%
countries = ["India", "Australia"," Iran"];
print(countries);
print("Value at index 0:",countries[0]);
countries[0] = "Japan";
print("Value at index 0:",countries[0]);
# Out:
# ['India', 'Australia', ' Iran']
# Value at index 0: India
# Value at index 0: Japan

# %%
hybridlist = ["My name is", "Aniruddha Seth", "My age is: ", 21];
for item in hybridlist:
  print(item)
# Out:
# My name is
# Aniruddha Seth
# My age is:
# 21

# %%
countries = ["India", "Australia"," Iran"];
for index, country in enumerate(countries):
  place = str(index)
  print("Country at index " + place + " is " + country)
# Out:
# Country at index 0 is India
# Country at index 1 is Australia
# Country at index 2 is  Iran

# %%
del countries[-1]
print(countries)
# Out:
# ['India', 'Australia']

# %%
l = [1,2,3,4,5]
for i in l:
  print(i)

[i for i in l]
l = [2, 4, 6, 8, 10]
[i**2 for i in l if i**2 < 50]
# Out:
# 1
# 2
# 3
# 4
# 5
# [4, 16, 36]

# %%
l2 = [1 if i>5 else 0 for i in l]
print(l2)
l = [1,2,3,4,5]
[27*x for x in l if( x**2 <= 10)]
# Out:
# [0, 0, 1, 1, 1]
# [27, 54, 81]

# %%
[i for i in l if (i%2 ==0)]
# Out:
# [2, 4]

# %%
[i for i in l if (i%2 ==0 and i%5 ==0)]
# Out:
# []

# %%
[i + 5 for i in range(51) if(i/5 == 0 and i < 30)]
# Out:
# [5]

# %%
j = [i for i in "I love CSIT" if  i in ['a', 'e', 'i', 'o', 'u']]
print(j)
# Out:
# ['o', 'e']

# %%
l = [1,5,6,7,8,46,578,768];
p = [i for i in l if(i%2 != 0)]
for i in p:
  l.remove(i);

print(l)
# Out:
# [6, 8, 46, 578, 768]

# %%
list_a = [1, 2, 3, 4]
list_b = [2, 3, 4, 5]
[i for i in list_a if (i in list_b)]
# Out:
# [2, 3, 4]
